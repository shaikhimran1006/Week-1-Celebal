# %% [markdown]
# **Titanic Dataset - Exploratory Data Analysis (EDA)**

# %% [markdown]
# 1. Load the Titanic Dataset

# %%
import pandas as pd
df = pd.read_csv('tested.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# 2. Check Data Summary and Missing Values

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
#         PassengerId    Survived      Pclass                      Name   Sex  \
# count    418.000000  418.000000  418.000000                       418   418
# ...

# %% [markdown]
#  Missing Value Detection

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False, cmap="Blues")
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False, cmap="Blues")
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df.drop('Cabin', axis=1, inplace=True)
# Out:
# <ipython-input-3-3222711227>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# <ipython-input-3-3222711227>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# 3. Univariate Analysis

# %% [markdown]
# Categorical: Sex, Embarked, Pclass

# %%
sns.countplot(x='Sex', data=df)
sns.countplot(x='Pclass', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Numerical: Age, Fare

# %%
sns.histplot(df['Age'], bins=30, kde=True)
sns.histplot(df['Fare'], bins=40, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# 4. Bivariate Analysis

# %% [markdown]
# Survival vs Gender/Class

# %%
sns.barplot(x='Sex', y='Survived', data=df)
sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# Boxplots for distribution comparison

# %%
sns.boxplot(x='Survived', y='Age', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# 5. Insights from Analysis
# ✅ Findings
# Females survived more.
#
# First-class passengers had better chances.
#
# Age and fare showed interesting trends.

# %% [markdown]
# 6. Survival Analysis

# %%
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack')
sns.histplot(data=df, x='Fare', hue='Survived', multiple='stack')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# 7. Feature Engineering

# %% [markdown]
# Create FamilySize Feature

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %% [markdown]
# IsAlone Feature

# %%
df['IsAlone'] = 1 # default
df.loc[df['FamilySize'] > 1, 'IsAlone'] = 0

# %% [markdown]
# 8.Advanced Visualization (Heatmap)

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %% [markdown]
# #Conclusion and Analysis of Titanic Dataset
# Data cleaning (missing values, outliers) is essential.
#
# Strong predictors: Sex, Pclass, Fare, IsAlone.
#
# Insights can be used for logistic regression, decision trees, or random forest classification models.
